# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <center><b><h1>Kalp Viradia | 23010101299 | 10/02/2025</b></center>
# <pre>

# %% [markdown]
# # Modules

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %%
from cal import add, multiply, subtract, divide

print(add(1,2))
print(subtract(1,2))
print(multiply(1,2))
print(divide(1,2))
# Out:
# 3
# -1
# 2
# 0.5

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random
s = 'python'
print(random.choice(s))
# Out:
# h

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
import random
l1 = [1,2,3,4,5]
print(random.choice(l1))
# Out:
# 2

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
import random

random.seed(1)

def roll_dice():
    return random.randint(1,6)

print(roll_dice())
# Out:
# 2

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random

def get_random_integer():
    count = 0
    l1 = []
    while count != 3:
        random_number = random.randint(100, 999)
        
        if random_number % 5 == 0:
            l1.append(random_number)
            count += 1
            
    return l1

print(get_random_integer())
# Out:
# [950, 525, 900]

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
import random

tickets = [''.join(random.choices('0123456789', k = 6)) for _ in range(100)]

winner = random.choice(tickets)
tickets.remove(winner)
runner_up = random.choice(tickets)

print(f"Winner: Ticket {winner}")
print(f"Runner-up: Ticket {runner_up}")
# Out:
# Winner: Ticket 876020
# Runner-up: Ticket 193596

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime

current_time = datetime.datetime.now()

print(current_time)
# Out:
# 2025-02-11 10:24:20.989901

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
import datetime

new_date = datetime.datetime.now() - datetime.timedelta(weeks = 1)

print(f"Date after subtracting a week: {new_date}")
# Out:
# Date after subtracting a week: 2025-02-04 10:25:27.316088

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
import datetime

start_date = datetime.date(2025, 2, 4)
end_date = datetime.date(2025, 2, 11)

no_of_days = abs(start_date - end_date)

print(no_of_days)
# Out:
# 7 days, 0:00:00

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
import datetime

given_date = datetime.date(2025, 2, 11) 

day_name = given_date.strftime("%A")

print("Day Name:", day_name)
# Out:
# Day Name: Tuesday

# %% [markdown]
# ### 11) WAP to demonstrate the use of date time module.

# %%
import datetime

print(datetime.datetime.now())
# Out:
# 2025-02-11 10:28:08.166593

# %% [markdown]
# ### 12) WAP to demonstrate the use of the math module.

# %%
import math

print(math.pow(5,2))
print(math.gcd(2,8))
print(math.sqrt(25))
print(math.factorial(5))
print(math.log(10))
print(math.pi)
print(math.e)
print(math.tan(math.pi/2))
print(math.sin(math.pi/2))
print(math.cos(math.pi/2))
print(math.ceil(3.7))
print(math.floor(3.7))
print(math.fabs(-3.7))
print(math.fmod(10,3))
print(math.trunc(3.7))
print(math.fsum([1,2,3,4,5]))
print(math.prod([1,2,3,4,5]))
print(math.gcd(12,18))
print(math.lcm(12,18))
print(math.perm(5,2))
print(math.gcd(12,18))
print(math.comb(5,2))
print(math.trunc(3.7))
print(math.fsum([1,2,3,4,5]))
print(math.prod([1,2,3,4,5]))
print(math.lcm(12,18))
# Out:
# 25.0
# 2
# 5.0
# 120
# 2.302585092994046
# 3.141592653589793
# 2.718281828459045
# 1.633123935319537e+16
# 1.0
# 6.123233995736766e-17
# 4
# 3
# 3.7
# 1.0
# 3
# 15.0
# 120
# 6
# 36
# 20
# 6
# 10
# 3
# 15.0
# 120
# 36
